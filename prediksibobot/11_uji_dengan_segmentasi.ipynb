# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
import numpy as np
import os
import zipfile
import cv2
import matplotlib.pyplot as plt

# %%
zip_path = '/content/dataset2.zip'
extract_path = '/content/'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f'File berhasil diekstrak ke {extract_path}')
# Out:
# File berhasil diekstrak ke /content/

# %%
def canny_edge_detection(image_array):
    gray_image = cv2.cvtColor(image_array.astype('float32'), cv2.COLOR_RGB2GRAY)
    edges = cv2.Canny(np.uint8(gray_image*255), threshold1=100, threshold2=200)
    return edges

# %%
def show_images(original_img, segmented_img):
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    axes[0].imshow(original_img)
    axes[0].set_title("Gambar asli")
    axes[0].axis("off")

    axes[1].imshow(segmented_img, cmap='gray')
    axes[1].set_title("Canny Edge Segmentation")
    axes[1].axis("off")

    plt.show()

# %%
image_dir = '/content/dataset2'

images = []
labels = []

data_gen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    fill_mode='nearest'
)

images = []
labels = []

for filename in os.listdir(image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(image_dir, filename)
        img = load_img(img_path, target_size=(224, 224))
        img_array = img_to_array(img) / 255.0
        edges = canny_edge_detection(img_array)
        edges = np.expand_dims(edges, axis=-1)
        label = int(filename.split('.')[0])
        images.append(edges)
        labels.append(label)

X = np.array(images)
y = np.array(labels)

# %%
def select_image_by_path(image_path):
    if os.path.exists(image_path):
        img = load_img(image_path, target_size=(224, 224))
        img_array = img_to_array(img) / 255.0
        return img_array
    else:
        print(f"Gambar dengan path {image_path} tidak ditemukan!")
        return None

image_path = '/content/dataset2/180.jpg'
selected_image = select_image_by_path(image_path)

if selected_image is not None:
    segmented_image = canny_edge_detection(selected_image)
    show_images(selected_image, segmented_image)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 1)),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_model.keras',
    monitor='loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

history = model.fit(
    X, y,
    epochs=500,
    batch_size=32,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 308317.7812 - mae: 497.1911
# Epoch 1: loss improved from inf to 308317.78125, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 308317.7812 - mae: 497.1911
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 5456889.0000 - mae: 2289.3982
# Epoch 2: loss did not improve from 308317.78125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 5456889.0000 - mae: 2289.3982
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 60495.8516 - mae: 193.7389
# Epoch 3: loss improved from 308317.78125 to 60495.85156, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 60495.8516 - mae: 193.7389
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 429638.4688 - mae: 610.2911
# Epoch 4: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 429638.4688 - mae: 610.2911
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 368988.7812 - mae: 556.6961
# Epoch 5: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 368988.7812 - mae: 556.6961
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 328984.7188 - mae: 518.3380
# Epoch 6: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 328984.7188 - mae: 518.3380
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 297590.7188 - mae: 486.0052
# Epoch 7: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 297590.7188 - mae: 486.0052
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 273809.0000 - mae: 460.7570
# Epoch 8: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 273809.0000 - mae: 460.7570
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 257063.7656 - mae: 442.4552
# Epoch 9: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 257063.7656 - mae: 442.4552
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 244817.2344 - mae: 428.7039
# Epoch 10: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 244817.2344 - mae: 428.7039
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 235441.5156 - mae: 417.8920
# Epoch 11: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 235441.5156 - mae: 417.8920
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 227213.5938 - mae: 408.4748
# Epoch 12: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 227213.5938 - mae: 408.4748
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 219182.7344 - mae: 398.9325
# Epoch 13: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 219182.7344 - mae: 398.9325
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 210172.3438 - mae: 387.8376
# Epoch 14: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 210172.3438 - mae: 387.8376
# Epoch 15/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 199298.6406 - mae: 374.0802
# Epoch 15: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 199298.6406 - mae: 374.0802
# Epoch 16/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 185615.0469 - mae: 356.0534
# Epoch 16: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 185615.0469 - mae: 356.0534
# Epoch 17/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 168082.7969 - mae: 331.5413
# Epoch 17: loss did not improve from 60495.85156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss:
# Epoch 43/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 2833.4944 - mae: 47.3317
# Epoch 43: loss did not improve from 1638.31531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 2833.4944 - mae: 47.3317
# Epoch 44/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4409.2114 - mae: 59.3524
# Epoch 44: loss did not improve from 1638.31531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4409.2114 - mae: 59.3524
# Epoch 45/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4963.4263 - mae: 64.4061
# Epoch 45: loss did not improve from 1638.31531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4963.4263 - mae: 64.4061
# Epoch 46/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4348.7310 - mae: 59.3810
# Epoch 46: loss did not improve from 1638.31531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4348.7310 - mae: 59.3810
# Epoch 47/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3066.2241 - mae: 47.6701
# Epoch 47: loss did not improve from 1638.31531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3066.2241 - mae: 47.6701
# Epoch 48/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1819.7974 - mae: 37.3042
# Epoch 48: loss did not improve from 1638.31531
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1819.7974 - mae: 37.3042
# Epoch 49/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1053.0599 - mae: 28.6637
# Epoch 49: loss improved from 1638.31531 to 1053.05994, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1053.0599 - mae: 28.6637
# Epoch 50/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 863.5897 - mae: 22.6079
# Epoch 50: loss improved from 1053.05994 to 863.58966, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 863.5897 - mae: 22.6079
# Epoch 51/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1024.3815 - mae: 23.6326
# Epoch 51: loss did not improve from 863.58966
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1024.3815 - mae: 23.6326
# Epoch 52/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1138.6827 - mae: 28.6066
# Epoch 52: loss did not improve from 863.58966
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1138.6827 - mae: 28.6066
# Epoch 53/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 985.8640 - mae: 28.0816
# Epoch 53: loss did not improve from 863.58966
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 985.8640 - mae: 28.0816
# Epoch 54/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 630.2015 - mae: 23.2604
# Epoch 54: loss improved from 863.58966 to 630.20148, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 630.2015 - mae: 23.2604
# Epoch 55/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 311.6949 - mae: 16.2844
# Epoch 55: loss improved from 630.20148 to 311.69485, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 311.6949 - mae: 16.2844
# Epoch 56/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 222.1644 - mae: 11.9170
# Epoch 56: loss improved from 311.69485 to 222.16437, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 222.1644 - mae: 11.9170
# Epoch 57/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 376.9878 - mae: 13.3648
# Epoch 57: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 376.9878 - mae: 13.3648
# Epoch 58/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 641.0101 - mae: 15.6364
# Epoch 58: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 641.0101 - mae: 15.6364
# Epoch 59/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 841.9169 - mae: 18.1559
# Epoch 59: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 841.9169 - mae: 18.1559
# Epoch 60/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 874.1908 - mae: 18.7541
# Epoch 60: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 874.1908 - mae: 18.7541
# Epoch 61/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 739.4908 - mae: 17.4308
# Epoch 61: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 739.4908 - mae: 17.4308
# Epoch 62/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 526.0860 - mae: 16.5377
# Epoch 62: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 526.0860 - mae: 16.5377
# Epoch 63/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 345.7308 - mae: 15.4252
# Epoch 63: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 345.7308 - mae: 15.4252
# Epoch 64/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 267.6285 - mae: 14.1392
# Epoch 64: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 267.6285 - mae: 14.1392
# Epoch 65/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 281.3511 - mae: 15.3499
# Epoch 65: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 281.3511 - mae: 15.3499
# Epoch 66/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 315.2529 - mae: 16.3465
# Epoch 66: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 315.2529 - mae: 16.3465
# Epoch 67/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 297.8908 - mae: 16.5971
# Epoch 67: loss did not improve from 222.16437
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 297.8908 - mae: 16.5971
# Epoch 68/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 212.3805 - mae: 14.0286
# Epoch 68: loss improved from 222.16437 to 212.38046, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 212.3805 - mae: 14.0286
# Epoch 69/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 102.4189 - mae: 9.2808
# Epoch 69: loss improved from 212.38046 to 102.41888, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 102.4189 - mae: 9.2808
# Epoch 70/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 30.2433 - mae: 4.3660
# Epoch 70: loss improved from 102.41888 to 30.24330, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 30.2433 - mae: 4.3660
# Epoch 71/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 27.9295 - mae: 4.7961
# Epoch 71: loss improved from 30.24330 to 27.92946, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss:
# Epoch 105/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 5.1830 - mae: 1.7285
# Epoch 105: loss did not improve from 1.79162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 5.1830 - mae: 1.7285
# Epoch 106/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 6.9114 - mae: 1.8023
# Epoch 106: loss did not improve from 1.79162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 6.9114 - mae: 1.8023
# Epoch 107/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 7.2374 - mae: 1.8186
# Epoch 107: loss did not improve from 1.79162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 7.2374 - mae: 1.8186
# Epoch 108/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 5.7048 - mae: 1.5699
# Epoch 108: loss did not improve from 1.79162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 5.7048 - mae: 1.5699
# Epoch 109/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.3555 - mae: 1.2026
# Epoch 109: loss did not improve from 1.79162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.3555 - mae: 1.2026
# Epoch 110/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.6698 - mae: 1.0803
# Epoch 110: loss improved from 1.79162 to 1.66979, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 1.6698 - mae: 1.0803
# Epoch 111/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.3197 - mae: 1.0440
# Epoch 111: loss improved from 1.66979 to 1.31967, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.3197 - mae: 1.0440
# Epoch 112/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.8176 - mae: 1.1683
# Epoch 112: loss did not improve from 1.31967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 1.8176 - mae: 1.1683
# Epoch 113/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.1817 - mae: 1.2698
# Epoch 113: loss did not improve from 1.31967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 2.1817 - mae: 1.2698
# Epoch 114/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.8710 - mae: 1.0888
# Epoch 114: loss did not improve from 1.31967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 1.8710 - mae: 1.0888
# Epoch 115/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 1.1539 - mae: 0.7776
# Epoch 115: loss improved from 1.31967 to 1.15394, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1539 - mae: 0.7776
# Epoch 116/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.7001 - mae: 0.6972
# Epoch 116: loss improved from 1.15394 to 0.70008, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.7001 - mae: 0.6972
# Epoch 117/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.8902 - mae: 0.8167
# Epoch 117: loss did not improve from 0.70008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.8902 - mae: 0.8167
# Epoch 118/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.4867 - mae: 0.9996
# Epoch 118: loss did not improve from 0.70008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.4867 - mae: 0.9996
# Epoch 119/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.9111 - mae: 1.2063
# Epoch 119: loss did not improve from 0.70008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.9111 - mae: 1.2063
# Epoch 120/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.7886 - mae: 1.1619
# Epoch 120: loss did not improve from 0.70008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.7886 - mae: 1.1619
# Epoch 121/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.2387 - mae: 0.9237
# Epoch 121: loss did not improve from 0.70008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.2387 - mae: 0.9237
# Epoch 122/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.6923 - mae: 0.7469
# Epoch 122: loss improved from 0.70008 to 0.69228, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.6923 - mae: 0.7469
# Epoch 123/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.4707 - mae: 0.5916
# Epoch 123: loss improved from 0.69228 to 0.47072, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.4707 - mae: 0.5916
# Epoch 124/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.5434 - mae: 0.5730
# Epoch 124: loss did not improve from 0.47072
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.5434 - mae: 0.5730
# Epoch 125/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.6391 - mae: 0.6262
# Epoch 125: loss did not improve from 0.47072
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.6391 - mae: 0.6262
# Epoch 126/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.5480 - mae: 0.6179
# Epoch 126: loss did not improve from 0.47072
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.5480 - mae: 0.6179
# Epoch 127/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.3078 - mae: 0.4822
# Epoch 127: loss improved from 0.47072 to 0.30776, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.3078 - mae: 0.4822
# Epoch 128/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.1245 - mae: 0.3094
# Epoch 128: loss improved from 0.30776 to 0.12449, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.1245 - mae: 0.3094
# Epoch 129/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.1489 - mae: 0.3110
# Epoch 129: loss did not improve from 0.12449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.1489 - mae: 0.3110
# Epoch 130/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3358 - mae: 0.4064
# Epoch 130: loss did not improve from 0.12449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.3358 - mae: 0.4064
# Epoch 131/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.5051 - mae: 0.4653
# Epoch 131: loss did not improve from 0.12449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.5051 - mae: 0.4653
# Epoch 132/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.5191 - mae: 0.4848
# Epoch 132: loss did not improve from 0.12449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.5191 - mae: 0.4848
# Epoch 133/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.3940 - mae: 0.4754
# Epoch 133: loss did not improve from 0.12449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.3940 - mae: 0.4754
# Epoch 134/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.2543 - mae: 0.4492
# Epoch 134: loss did not improve from 0.12449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.2543 - mae: 0.4492
# Epoch 135/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.1990 - mae: 0.4008
# Epoch 135: loss did not improve from 0.12449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.1990 - mae: 0.4008
# Epoch 136/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2190 - mae: 0.3975
# Epoch 136: loss did not improve from 0.12449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.2190 - mae: 0.3975
# Epoch 137/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2318 - mae: 0.4432
# Epoch 137: loss did not improve from 0.12449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.2318 - mae: 0.4432
# Epoch 138/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.1793 - mae: 0.4011
# Epoch 138: loss did not improve from 0.12449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.1793 - mae: 0.4011
# Epoch 139/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0839 - mae: 0.2682
# Epoch 139: loss improved from 0.12449 to 0.08394, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0839 - mae: 0.2682
# Epoch 140/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0167 - mae: 0.1098
# Epoch 140: loss improved from 0.08394 to 0.01666, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0167 - mae: 0.1098
# Epoch 141/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0215 - mae: 0.1243
# Epoch 141: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0215 - mae: 0.1243
# Epoch 142/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0766 - mae: 0.2531
# Epoch 142: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0766 - mae: 0.2531
# Epoch 143/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.1230 - mae: 0.3256
# Epoch 143: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.1230 - mae: 0.3256
# Epoch 144/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.1239 - mae: 0.3145
# Epoch 144: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.1239 - mae: 0.3145
# Epoch 145/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0922 - mae: 0.2544
# Epoch 145: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0922 - mae: 0.2544
# Epoch 146/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0665 - mae: 0.2386
# Epoch 146: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0665 - mae: 0.2386
# Epoch 147/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0678 - mae: 0.2286
# Epoch 147: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0678 - mae: 0.2286
# Epoch 148/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0822 - mae: 0.2064
# Epoch 148: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0822 - mae: 0.2064
# Epoch 149/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0821 - mae: 0.1861
# Epoch 149: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0821 - mae: 0.1861
# Epoch 150/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0575 - mae: 0.1529
# Epoch 150: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0575 - mae: 0.1529
# Epoch 151/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0249 - mae: 0.1054
# Epoch 151: loss did not improve from 0.01666
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0249 - mae: 0.1054
# Epoch 152/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0078 - mae: 0.0707
# Epoch 152: loss improved from 0.01666 to 0.00779, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0078 - mae: 0.0707
# Epoch 153/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0132 - mae: 0.0968
# Epoch 153: loss did not improve from 0.00779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0132 - mae: 0.0968
# Epoch 154/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0277 - mae: 0.1312
# Epoch 154: loss did not improve from 0.00779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0277 - mae: 0.1312
# Epoch 155/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0340 - mae: 0.1407
# Epoch 155: loss did not improve from 0.00779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0340 - mae: 0.1407
# Epoch 156/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0278 - mae: 0.1170
# Epoch 156: loss did not improve from 0.00779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0278 - mae: 0.1170
# Epoch 157/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0188 - mae: 0.1063
# Epoch 157: loss did not improve from 0.00779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0188 - mae: 0.1063
# Epoch 158/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0172 - mae: 0.1249
# Epoch 158: loss did not improve from 0.00779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0172 - mae: 0.1249
# Epoch 159/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0229 - mae: 0.1351
# Epoch 159: loss did not improve from 0.00779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0229 - mae: 0.1351
# Epoch 160/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0272 - mae: 0.1446
# Epoch 160: loss did not improve from 0.00779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0272 - mae: 0.1446
# Epoch 161/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0231 - mae: 0.1347
# Epoch 161: loss did not improve from 0.00779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0231 - mae: 0.1347
# Epoch 162/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0128 - mae: 0.0954
# Epoch 162: loss did not improve from 0.00779
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0128 - mae: 0.0954
# Epoch 163/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0045 - mae: 0.0580
# Epoch 163: loss improved from 0.00779 to 0.00450, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0045 - mae: 0.0580
# Epoch 164/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0031 - mae: 0.0476
# Epoch 164: loss improved from 0.00450 to 0.00313, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0031 - mae: 0.0476
# Epoch 165/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0066 - mae: 0.0666
# Epoch 165: loss did not improve from 0.00313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0066 - mae: 0.0666
# Epoch 166/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0091 - mae: 0.0868
# Epoch 166: loss did not improve from 0.00313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0091 - mae: 0.0868
# Epoch 167/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0078 - mae: 0.0803
# Epoch 167: loss did not improve from 0.00313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0078 - mae: 0.0803
# Epoch 168/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0051 - mae: 0.0624
# Epoch 168: loss did not improve from 0.00313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0051 - mae: 0.0624
# Epoch 169/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0045 - mae: 0.0601
# Epoch 169: loss did not improve from 0.00313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0045 - mae: 0.0601
# Epoch 170/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0067 - mae: 0.0628
# Epoch 170: loss did not improve from 0.00313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0067 - mae: 0.0628
# Epoch 171/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0091 - mae: 0.0688
# Epoch 171: loss did not improve from 0.00313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0091 - mae: 0.0688
# Epoch 172/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0088 - mae: 0.0673
# Epoch 172: loss did not improve from 0.00313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0088 - mae: 0.0673
# Epoch 173/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0059 - mae: 0.0554
# Epoch 173: loss did not improve from 0.00313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0059 - mae: 0.0554
# Epoch 174/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0029 - mae: 0.0435
# Epoch 174: loss improved from 0.00313 to 0.00289, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0029 - mae: 0.0435
# Epoch 175/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0018 - mae: 0.0383
# Epoch 175: loss improved from 0.00289 to 0.00183, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0018 - mae: 0.0383
# Epoch 176/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - loss: 0.0024 - mae: 0.0445
# Epoch 176: loss did not improve from 0.00183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0024 - mae: 0.0445
# Epoch 177/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0028 - mae: 0.0484
# Epoch 177: loss did not improve from 0.00183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0028 - mae: 0.0484
# Epoch 178/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0021 - mae: 0.0386
# Epoch 178: loss did not improve from 0.00183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0021 - mae: 0.0386
# Epoch 179/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 9.6326e-04 - mae: 0.0216
# Epoch 179: loss improved from 0.00183 to 0.00096, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 9.6326e-04 - mae: 0.0216
# Epoch 180/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.9071e-04 - mae: 0.0224
# Epoch 180: loss improved from 0.00096 to 0.00069, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 6.9071e-04 - mae: 0.0224
# Epoch 181/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.0015 - mae: 0.0351
# Epoch 181: loss did not improve from 0.00069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0015 - mae: 0.0351
# Epoch 182/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0025 - mae: 0.0446
# Epoch 182: loss did not improve from 0.00069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0025 - mae: 0.0446
# Epoch 183/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.0026 - mae: 0.0459
# Epoch 183: loss did not improve from 0.00069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0026 - mae: 0.0459
# Epoch 184/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0019 - mae: 0.0382
# Epoch 184: loss did not improve from 0.00069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0019 - mae: 0.0382
# Epoch 185/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0011 - mae: 0.0314
# Epoch 185: loss did not improve from 0.00069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0011 - mae: 0.0314
# Epoch 186/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 8.6373e-04 - mae: 0.0234
# Epoch 186: loss did not improve from 0.00069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 8.6373e-04 - mae: 0.0234
# Epoch 187/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0010 - mae: 0.0230
# Epoch 187: loss did not improve from 0.00069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0010 - mae: 0.0230
# Epoch 188/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0011 - mae: 0.0244
# Epoch 188: loss did not improve from 0.00069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0011 - mae: 0.0244
# Epoch 189/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 6.9098e-04 - mae: 0.0213
# Epoch 189: loss did not improve from 0.00069
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 6.9098e-04 - mae: 0.0213
# Epoch 190/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2.4882e-04 - mae: 0.0133
# Epoch 190: loss improved from 0.00069 to 0.00025, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 2.4882e-04 - mae: 0.0133
# Epoch 191/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 1.6884e-04 - mae: 0.0105
# Epoch 191: loss improved from 0.00025 to 0.00017, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.6884e-04 - mae: 0.0105
# Epoch 192/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 4.6805e-04 - mae: 0.0158
# Epoch 192: loss did not improve from 0.00017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 4.6805e-04 - mae: 0.0158
# Epoch 193/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.7590e-04 - mae: 0.0188
# Epoch 193: loss did not improve from 0.00017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 7.7590e-04 - mae: 0.0188
# Epoch 194/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 7.8715e-04 - mae: 0.0193
# Epoch 194: loss did not improve from 0.00017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 7.8715e-04 - mae: 0.0193
# Epoch 195/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 5.5810e-04 - mae: 0.0179
# Epoch 195: loss did not improve from 0.00017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 5.5810e-04 - mae: 0.0179
# Epoch 196/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.6388e-04 - mae: 0.0167
# Epoch 196: loss did not improve from 0.00017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.6388e-04 - mae: 0.0167
# Epoch 197/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.6096e-04 - mae: 0.0166
# Epoch 197: loss did not improve from 0.00017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.6096e-04 - mae: 0.0166
# Epoch 198/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 4.2487e-04 - mae: 0.0183
# Epoch 198: loss did not improve from 0.00017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 4.2487e-04 - mae: 0.0183
# Epoch 199/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.7233e-04 - mae: 0.0181
# Epoch 199: loss did not improve from 0.00017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.7233e-04 - mae: 0.0181
# Epoch 200/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.9293e-04 - mae: 0.0128
# Epoch 200: loss did not improve from 0.00017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.9293e-04 - mae: 0.0128
# Epoch 201/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.0255e-05 - mae: 0.0051
# Epoch 201: loss improved from 0.00017 to 0.00004, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 4.0255e-05 - mae: 0.0051
# Epoch 202/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 4.0802e-05 - mae: 0.0055
# Epoch 202: loss did not improve from 0.00004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 4.0802e-05 - mae: 0.0055
# Epoch 203/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.4888e-04 - mae: 0.0113
# Epoch 203: loss did not improve from 0.00004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.4888e-04 - mae: 0.0113
# Epoch 204/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 2.2431e-04 - mae: 0.0140
# Epoch 204: loss did not improve from 0.00004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 2.2431e-04 - mae: 0.0140
# Epoch 205/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 2
500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 8.3980e-06 - mae: 0.0024
# Epoch 232: loss improved from 0.00001 to 0.00001, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 8.3980e-06 - mae: 0.0024
# Epoch 233/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 4.8840e-06 - mae: 0.0019
# Epoch 233: loss improved from 0.00001 to 0.00000, saving model to best_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 4.8840e-06 - mae: 0.0019
# Epoch 234/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 5.8370e-06 - mae: 0.0022
# Epoch 234: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 5.8370e-06 - mae: 0.0022
# Epoch 235/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 7.1163e-06 - mae: 0.0025
# Epoch 235: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 7.1163e-06 - mae: 0.0025
# Epoch 236/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 5.0893e-06 - mae: 0.0020
# Epoch 236: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 5.0893e-06 - mae: 0.0020
# Epoch 237/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 1.9971e-06 - mae: 0.0011
# ...
# Epoch 423/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 423: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 424/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 424: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 425/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 425: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 426/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 426: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 427/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 427: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 428/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 428: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 429/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 429: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 430/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 430: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 431/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 431: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 432/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 432: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 433/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 433: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 434/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 434: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 435/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 435: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 436/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 436: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 437/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 437: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 438/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 438: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 439/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 439: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 440/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 440: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 441/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 441: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 442/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 442: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.8100e-10 - mae: 8.3230e-06
# Epoch 443/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 443: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 444/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 444: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.4449e-10 - mae: 9.7101e-06
# Epoch 445/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 445: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 446/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 446: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 447/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 447: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 448/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 448: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 449/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 449: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 450/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 450: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 451/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 451: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 452/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 452: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 453/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 453: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 454/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 454: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 455/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 455: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 456/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 456: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 457/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 457: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 458/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 458: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 459/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 459: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 460/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 460: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 461/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 461: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 462/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 462: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 463/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 463: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 464/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 464: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 465/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 465: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 466/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 466: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 467/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 467: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 468/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 468: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 469/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 469: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 470/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 470: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 471/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 471: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 472/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 472: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 473/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 473: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 474/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 474: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 475/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 475: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 476/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 476: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 477/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 477: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 478/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 478: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 479/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 479: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 480/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 480: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 481/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 481: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 482/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 482: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 483/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 483: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 484/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 484: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 485/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 485: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 486/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 486: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 487/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 487: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 488/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 488: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 489/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 489: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 490/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 490: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 491/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 491: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 492/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 492: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 493/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 493: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 494/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 494: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 495/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 495: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 496/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 496: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 497/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 497: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 498/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 498: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 499/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 499: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 500/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06
# Epoch 500: loss did not improve from 0.00000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.5983e-10 - mae: 6.9358e-06

# %%
import zipfile
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import math

test_zip_path = '/content/dataset2.zip'
test_extract_path = '/content/'

with zipfile.ZipFile(test_zip_path, 'r') as zip_ref:
    zip_ref.extractall(test_extract_path)

print(f'File berhasil diekstrak ke {test_extract_path}')

image_dir = '/content/dataset2'

images = []
labels = []

for filename in os.listdir(image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(image_dir, filename)
        img = load_img(img_path, target_size=(224, 224))
        img_array = img_to_array(img) / 255.0

        label = int(filename.split('.')[0])

        images.append(img_array)
        labels.append(label)

X = np.array(images)
y = np.array(labels)


best_model = tf.keras.models.load_model('best_model.keras')
prediksi_bobot = best_model.predict(X)
selisih = np.abs(y - prediksi_bobot.flatten())
persentase_kebenaran = 100 * (1 - selisih / y)
rata_rata_persentase = np.mean(persentase_kebenaran)


num_images = len(X)
cols = 5
rows = math.ceil(num_images / cols)

plt.figure(figsize=(cols * 3, rows * 3))

for i in range(num_images):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(X[i])
    plt.axis('off')
    plt.title(f"Aktual: {y[i]} kg\nPrediksi: {prediksi_bobot[i][0]:.2f} kg\nSelisih: {selisih[i]:.2f} kg\nKebenaran: {persentase_kebenaran[i]:.2f}%", fontsize=8, color='black')

plt.suptitle(f"Rata-rata Persentase Kebenaran: {rata_rata_persentase:.2f}%", fontsize=12, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# File berhasil diekstrak ke /content/
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step

# %%
import zipfile
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import math

test_zip_path = '/content/test_dataset.zip'
test_extract_path = '/content/'

with zipfile.ZipFile(test_zip_path, 'r') as zip_ref:
    zip_ref.extractall(test_extract_path)

print(f'File berhasil diekstrak ke {test_extract_path}')

image_dir = '/content/test_dataset'

images = []
labels = []

for filename in os.listdir(image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(image_dir, filename)
        img = load_img(img_path, target_size=(224, 224))
        img_array = img_to_array(img) / 255.0

        label = int(filename.split('.')[0])

        images.append(img_array)
        labels.append(label)

X = np.array(images)
y = np.array(labels)


best_model = tf.keras.models.load_model('best_model.keras')
prediksi_bobot = best_model.predict(X)
selisih = np.abs(y - prediksi_bobot.flatten())
persentase_kebenaran = 100 * (1 - selisih / y)
rata_rata_persentase = np.mean(persentase_kebenaran)


num_images = len(X)
cols = 5
rows = math.ceil(num_images / cols)

plt.figure(figsize=(cols * 3, rows * 3))

for i in range(num_images):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(X[i])
    plt.axis('off')
    plt.title(f"Aktual: {y[i]} kg\nPrediksi: {prediksi_bobot[i][0]:.2f} kg\nSelisih: {selisih[i]:.2f} kg\nKebenaran: {persentase_kebenaran[i]:.2f}%", fontsize=8, color='black')

plt.suptitle(f"Rata-rata Persentase Kebenaran: {rata_rata_persentase:.2f}%", fontsize=12, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# File berhasil diekstrak ke /content/
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 727ms/step

# %%
import zipfile
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import cv2
import matplotlib.pyplot as plt


test_zip_path = '/content/dataset2.zip'
test_extract_path = '/content/'
with zipfile.ZipFile(test_zip_path, 'r') as zip_ref:
    zip_ref.extractall(test_extract_path)

print(f'File berhasil diekstrak ke {test_extract_path}')

def canny_edge_detection(image_array):
    gray_image = cv2.cvtColor(image_array.astype('float32'), cv2.COLOR_RGB2GRAY)
    edges = cv2.Canny(np.uint8(gray_image * 255), threshold1=100, threshold2=200)
    return edges

image_dir = '/content/dataset2'

images = []
labels = []

# Memuat gambar dan label, serta menerapkan Canny Edge
for filename in os.listdir(image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(image_dir, filename)
        img = load_img(img_path, target_size=(224, 224))
        img_array = img_to_array(img) / 255.0

        # Hanya menggunakan Canny Edge
        edges = canny_edge_detection(img_array)
        edges = np.expand_dims(edges, axis=-1)
        label = int(filename.split('.')[0])
        images.append(edges)
        labels.append(label)

X = np.array(images)
y = np.array(labels)

best_model = tf.keras.models.load_model('best_model.keras')
prediksi_bobot = best_model.predict(X)
selisih = np.abs(y - prediksi_bobot.flatten())
persentase_kebenaran = 100 * (1 - selisih / y)
rata_rata_persentase = np.mean(persentase_kebenaran)

num_images = len(X)
cols = 5
rows = (num_images + cols - 1) // cols

plt.figure(figsize=(cols * 3, rows * 3))

for i in range(num_images):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(X[i][:, :, 0], cmap='gray')
    plt.axis('off')
    plt.title(f"Aktual: {y[i]} kg\nPrediksi: {prediksi_bobot[i][0]:.2f} kg\nSelisih: {selisih[i]:.2f} kg\nKebenaran: {persentase_kebenaran[i]:.2f}%", fontsize=8)

plt.suptitle(f"Rata-rata Persentase Kebenaran: {rata_rata_persentase:.2f}%", fontsize=12, y=1.02)
plt.tight_layout()
plt.show()

print(f'Rata-rata Persentase Kebenaran: {rata_rata_persentase:.2f}%')
# Out:
# File berhasil diekstrak ke /content/
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# Rata-rata Persentase Kebenaran: 100.00%

# %%
import zipfile
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import cv2
import matplotlib.pyplot as plt

test_zip_path = '/content/test.zip'
test_extract_path = '/content/'

with zipfile.ZipFile(test_zip_path, 'r') as zip_ref:
    zip_ref.extractall(test_extract_path)

print(f'File berhasil diekstrak ke {test_extract_path}')

# Fungsi untuk Canny Edge Detection
def canny_edge_detection(image_array):
    gray_image = cv2.cvtColor(image_array.astype('float32'), cv2.COLOR_RGB2GRAY)
    edges = cv2.Canny(np.uint8(gray_image * 255), threshold1=100, threshold2=200)
    return edges

image_dir = '/content/test'

images = []
labels = []

# Memuat gambar dan label, serta menerapkan Canny Edge
for filename in os.listdir(image_dir):
    if filename.endswith(".jpg"):
        img_path = os.path.join(image_dir, filename)
        img = load_img(img_path, target_size=(224, 224))
        img_array = img_to_array(img) / 255.0

        # Hanya menggunakan Canny Edge
        edges = canny_edge_detection(img_array)
        edges = np.expand_dims(edges, axis=-1)  # Menambahkan dimensi channel

        label = int(filename.split('.')[0])

        images.append(edges)
        labels.append(label)

X = np.array(images)
y = np.array(labels)

best_model = tf.keras.models.load_model('best_model.keras')
prediksi_bobot = best_model.predict(X)
selisih = np.abs(y - prediksi_bobot.flatten())
persentase_kebenaran = 100 * (1 - selisih / y)
rata_rata_persentase = np.mean(persentase_kebenaran)


num_images = len(X)
cols = 5
rows = (num_images + cols - 1) // cols

plt.figure(figsize=(cols * 3, rows * 3))

for i in range(num_images):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(X[i][:, :, 0], cmap='gray')
    plt.axis('off')
    plt.title(f"Aktual: {y[i]} kg\nPrediksi: {prediksi_bobot[i][0]:.2f} kg\nSelisih: {selisih[i]:.2f} kg\nKebenaran: {persentase_kebenaran[i]:.2f}%", fontsize=8)

plt.suptitle(f"Rata-rata Persentase Kebenaran: {rata_rata_persentase:.2f}%", fontsize=12, y=1.02)
plt.tight_layout()
plt.show()

# Menampilkan hasil statistik
print(f'Rata-rata Persentase Kebenaran: {rata_rata_persentase:.2f}%')
# Out:
# File berhasil diekstrak ke /content/
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# Rata-rata Persentase Kebenaran: 79.95%
